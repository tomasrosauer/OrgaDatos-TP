# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('propiedades-clean.csv')
df.tail()
# Out:
#         Unnamed: 0  created_on  year currency  \
# 221336      338151  2017-08-01  2017      USD
# 221337      338152  2017-08-01  2017      USD
# 221338      338154  2017-08-01  2017      USD
# 221339      338155  2017-08-01  2017      USD
# 221340      338156  2017-08-01  2017      USD
#
#                                               description  expenses  floor  \
# 221336  ALQUILER DE DEPARTAMENTO 2 AMBIENTES, 40 mts2 ...    2700.0    NaN
# 221337  venta 3 ambientes con cochera fija y cubierta ...    4385.0    NaN
# 221338  VENTA DEPARTAMENTO 2 AMBIENTES EN BELGRANODepa...    1600.0    NaN
# 221339  Excelente duplex 4 ambientes de 5m de frente x...       NaN    NaN
# 221340  Departameno 1º piso con balcon y terraza a est...       NaN    NaN
#
#         geonames_id                                        id        lat  \
# 221336    3436109.0  a1de3c3be7e6381dffb267240e123de8c324100b -34.583742
# 221337    3433775.0  6b119cac3825c981da11b037e41b0014096a3bed        NaN
# ...

# %% [markdown]
# ## How many rows in dataset?

# %%
len(df)
# Out:
# 221341

# %% [markdown]
# ### What datatypes are we dealing with?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221341 entries, 0 to 221340
# Data columns (total 24 columns):
# Unnamed: 0                    221341 non-null int64
# created_on                    221341 non-null object
# year                          221341 non-null int64
# currency                      200125 non-null object
# description                   221331 non-null object
# expenses                      30133 non-null float64
# floor                         24326 non-null float64
# geonames_id                   176375 non-null float64
# id                            221341 non-null object
# lat                           155883 non-null float64
# lon                           155883 non-null float64
# operation                     221341 non-null object
# place_name                    221279 non-null object
# place_with_parent_names       221341 non-null object
# price                         204141 non-null float64
# price_aprox_local_currency    204141 non-null float64
# ...

# %% [markdown]
# ### What are the basic statistics on the dataset?

# %%
df.describe()
# Out:
#           Unnamed: 0           year      expenses         floor   geonames_id  \
# count  221341.000000  221341.000000  3.013300e+04  24326.000000  1.763750e+05
# mean   168993.923765    2016.341297  3.856257e+03     16.350530  3.494400e+06
# std     98906.572674       0.783534  8.194879e+04    123.178274  4.272747e+05
# min         1.000000    2013.000000  1.000000e+00      1.000000  3.427208e+06
# 25%     75513.000000    2016.000000  1.000000e+03      2.000000  3.429617e+06
# 50%    171838.000000    2017.000000  1.900000e+03      3.000000  3.430813e+06
# 75%    254993.000000    2017.000000  3.800000e+03      7.000000  3.435607e+06
# max    338156.000000    2017.000000  1.000150e+07   7071.000000  6.693230e+06
#
#                  lat            lon         price  price_aprox_local_currency  \
# count  155883.000000  155883.000000  2.041410e+05                2.041410e+05
# mean      -34.579429     -58.504345  3.200065e+05                4.152598e+06
# ...

# %%
#CABA properties
caba = df.loc[df.state_name.str.contains('Capital Federal'), :]

#GBA Norte properties
gba_n = df.loc[df.state_name.str.contains('Bs.As. G.B.A. Zona Norte'), :]

#GBA Oeste properties
gba_o = df.loc[df.state_name.str.contains('Bs.As. G.B.A. Zona Oeste'), :]

#GBA Sur properties
gba_s = df.loc[df.state_name.str.contains('Bs.As. G.B.A. Zona Sur'), :]

# %% [markdown]
# ### How are the prices distributed in CABA?

# %%
no_outliers_caba = caba[np.abs(caba.price_usd_per_m2 - caba.price_usd_per_m2.mean()) <= (3 * caba.price_usd_per_m2.std())]

fig = plt.figure(figsize=(20, 10))
ax = plt.subplot(111)
ax.spines['left'].set_color('#1a1a1a')
ax.spines['bottom'].set_color('#1a1a1a')

ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left()

plt.xticks(fontsize=14, color='#1a1a1a')  
plt.yticks(fontsize=14, color='#1a1a1a')

plt.title('Distribución de precio por m2 en CABA', fontsize=30)
plt.xlabel('Precio (usd)', fontsize=20)
plt.ylabel('Frecuencia', fontsize=20)

plt.hist(no_outliers_caba.price_usd_per_m2, bins=100, color='grey');

# %% [markdown]
# ### How are the prices distributed in Bs.As. G.B.A. Zona Norte?

# %%
no_outliers_gba_n = gba_n[np.abs(gba_n.price_usd_per_m2 - gba_n.price_usd_per_m2.mean()) <= (3 * gba_n.price_usd_per_m2.std())]

fig = plt.figure(figsize=(20, 10))
ax = plt.subplot(111)
ax.spines['left'].set_color('#1a1a1a')
ax.spines['bottom'].set_color('#1a1a1a')

ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left()

plt.xticks(fontsize=14, color='#1a1a1a')  
plt.yticks(fontsize=14, color='#1a1a1a')

plt.title('Distribución de precio por m2 en Bs.As. G.B.A. Zona Norte', fontsize=30)
plt.xlabel('Precio (usd)', fontsize=20)
plt.ylabel('Frecuencia', fontsize=20)

plt.hist(no_outliers_gba_n.price_usd_per_m2, bins=100, color='darkred');

# %% [markdown]
# ### How are the prices distributed in Bs.As. G.B.A. Zona Oeste?

# %%
no_outliers_gba_o = gba_o[np.abs(gba_o.price_usd_per_m2 - gba_o.price_usd_per_m2.mean()) <= (3 * gba_o.price_usd_per_m2.std())]

fig = plt.figure(figsize=(20, 10))
ax = plt.subplot(111)
ax.spines['left'].set_color('#1a1a1a')
ax.spines['bottom'].set_color('#1a1a1a')

ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left()

plt.xticks(fontsize=14, color='#1a1a1a')  
plt.yticks(fontsize=14, color='#1a1a1a')

plt.title('Distribución de precio por m2 en Bs.As. G.B.A. Zona Oeste', fontsize=30)
plt.xlabel('Precio (usd)', fontsize=20)
plt.ylabel('Frecuencia', fontsize=20)

plt.hist(no_outliers_gba_o.price_usd_per_m2, bins=100);

# %% [markdown]
# ### How are the prices distributed in Bs.As. G.B.A. Zona Sur?

# %%
no_outliers_gba_s = gba_s[np.abs(gba_s.price_usd_per_m2 - gba_s.price_usd_per_m2.mean()) <= (3 * gba_s.price_usd_per_m2.std())]

fig = plt.figure(figsize=(20, 10))
ax = plt.subplot(111)
ax.spines['left'].set_color('#1a1a1a')
ax.spines['bottom'].set_color('#1a1a1a')

ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left()

plt.xticks(fontsize=14, color='#1a1a1a')  
plt.yticks(fontsize=14, color='#1a1a1a')

plt.title('Distribución de precio por m2 en Bs.As. G.B.A. Zona Sur', fontsize=30)
plt.xlabel('Precio (usd)', fontsize=20)
plt.ylabel('Frecuencia', fontsize=20)

plt.hist(no_outliers_gba_s.price_usd_per_m2, bins=100, color='darkviolet');
